# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
FallAllD = pd.read_pickle('FallAllD.pkl')
FallAllD['ActivityID'] = FallAllD['ActivityID'].apply(pd.to_numeric)
FallAllD['ActivityID'] = FallAllD['ActivityID'].astype(np.uint8)
# Out:
# 1783    123
# 1784    123
# 1785    124
# 1786    125
# 1787    125
# 1788    126
# 1789    126
# 1790    127
# 1791    128
# 1792    127
# 1793    125
# 1794    124
# 1795    122
# 1796    121
# 1797    121
# Name: ActivityID, dtype: uint8

# %%
FallAllD.loc[FallAllD['ActivityID'] < 0]
# Out:
# Empty DataFrame
# Columns: [SubjectID, Device, ActivityID, TrialNo, Acc, Gyr, Mag]
# Index: []

# %%
FallAllD.head(30)
# Out:
#     SubjectID Device  ActivityID  TrialNo  \
# 0           1  Waist          13        1
# 1           1  Waist          13        2
# 2           1  Waist          13        5
# 3           1  Waist          13        6
# 4           1  Waist          13        9
# 5           1  Waist          13       10
# 6           1  Waist          13       12
# 7           1  Waist          14        1
# 8           1  Waist          14        3
# 9           1  Waist          14        5
# 10          1  Waist          14        6
# 11          1  Waist          14        8
# 12          1  Waist          14        9
# 13          1  Waist          14       10
# 14          1  Waist          14       11
# 15          1  Waist          15        1
# 16          1  Waist          15        2
# 17          1  Waist          15        3
# 18          1  Waist          16        1
# 19          1  Waist          16        2
# 20          1  Waist          16        3
# 21          1  Waist          18        1
# 22          1  Waist          18        2
# 23          1  Waist          18        3
# 24          1  Waist          18        4
# 25          1  Waist          19        2
# 26          1  Waist          19        3
# 27          1  Waist          19        4
# 28          1  Waist          19        5
# 29          1  Waist          19        6
#
#                                                   Acc  \
# 0   [[4062, -1428, -45], [4190, -1422, -24], [4302...
# 1   [[3737, -1549, 158], [3729, -1553, 160], [3728...
# 2   [[3954, -401, -107], [3894, -346, -108], [3835...
# 3   [[3992, -682, -33], [3988, -694, -31], [3985, ...
# 4   [[2223, 167, -18], [2139, 222, -90], [2108, 25...
# 5   [[4022, -429, 328], [4023, -428, 327], [4018, ...
# 6   [[4014, -227, 371], [4017, -224, 376], [4023, ...
# 7   [[3759, -283, 1472], [3760, -287, 1473], [3768...
# 8   [[3962, 84, 813], [3959, 85, 814], [3956, 90, ...
# 9   [[3590, 513, 1808], [3592, 509, 1808], [3592, ...
# 10  [[3644, 356, 1657], [3640, 361, 1654], [3640, ...
# 11  [[3893, 380, 1018], [3886, 379, 1015], [3882, ...
# 12  [[3404, 1185, 1766], [3403, 1184, 1762], [3400...
# 13  [[2705, 1075, 2817], [2697, 1078, 2812], [2695...
# 14  [[3595, 653, 1688], [3596, 658, 1688], [3597, ...
# 15  [[3738, -576, 1417], [3734, -575, 1414], [3735...
# 16  [[3519, 411, 1936], [3526, 409, 1933], [3531, ...
# 17  [[3325, 1113, 2028], [3325, 1110, 2028], [3326...
# 18  [[3817, -528, 189], [3830, -543, 217], [3847, ...
# 19  [[3827, -1358, -120], [3819, -1362, -120], [38...
# 20  [[3826, 221, -695], [3799, 196, -771], [3784, ...
# 21  [[605, 3080, -2654], [607, 3078, -2651], [604,...
# 22  [[757, 3578, -1834], [754, 3581, -1833], [755,...
# 23  [[215, 3476, -2158], [216, 3478, -2159], [219,...
# 24  [[-437, -3592, 1932], [-434, -3590, 1932], [-4...
# 25  [[3566, -1854, 559], [3565, -1849, 557], [3569...
# 26  [[3877, -1139, 346], [3874, -1135, 346], [3878...
# 27  [[3925, -997, 334], [3919, -995, 339], [3915, ...
# 28  [[4049, -47, 287], [4047, -48, 287], [4043, -4...
# 29  [[4049, 110, 285], [4046, 108, 287], [4043, 10...
#
#                                                   Gyr  \
# 0   [[1355, 21, 159], [1334, -19, 168], [1318, -68...
# 1   [[-4, 0, -1], [-7, 11, -3], [-11, 11, -2], [-1...
# 2   [[177, 173, 177], [160, 183, 164], [152, 197, ...
# 3   [[12, 13, 9], [15, 12, 10], [11, 12, 9], [9, 1...
# 4   [[-396, -163, 33], [-338, -62, 54], [-272, 44,...
# 5   [[-29, 24, 0], [-25, 22, -4], [-30, 22, -3], [...
# 6   [[-46, 15, -15], [-47, 17, -15], [-47, 22, -12...
# 7   [[1, 18, -1], [2, 15, -1], [2, 14, -2], [1, 15...
# 8   [[-6, 13, 7], [-8, 14, 8], [-8, 13, 6], [-11, ...
# 9   [[-2, 36, -4], [-4, 34, -5], [-2, 32, -5], [0,...
# 10  [[7, 17, 8], [7, 18, 7], [7, 18, 4], [1, 21, 8...
# 11  [[-6, 1, 2], [-8, -4, 3], [-7, 0, 2], [-12, 2,...
# 12  [[18, 37, 5], [17, 40, 5], [16, 40, 7], [15, 3...
# 13  [[3, 20, -15], [5, 22, -15], [8, 22, -17], [10...
# 14  [[-25, 19, 17], [-28, 21, 16], [-35, 25, 18], ...
# 15  [[-7, 13, -1], [-6, 15, 0], [-5, 16, -1], [-7,...
# 16  [[-1, 25, -2], [0, 25, -1], [0, 22, 2], [0, 22...
# 17  [[-12, 24, 2], [-8, 23, 2], [-6, 17, 1], [-2, ...
# 18  [[1375, -281, -17], [1411, -268, -24], [1435, ...
# 19  [[4, 5, -1], [4, 6, 1], [3, 12, 1], [7, 10, 6]...
# 20  [[944, -51, -55], [963, -26, -50], [964, 1, -4...
# 21  [[-7, 18, 3], [-3, 17, 0], [-4, 20, 0], [-5, 1...
# 22  [[-6, 18, 2], [-3, 17, 3], [-5, 19, 1], [-1, 1...
# 23  [[-11, 18, 6], [-9, 14, 7], [-6, 17, 7], [-7, ...
# 24  [[-4, 15, -1], [-9, 15, 0], [-6, 12, 0], [-3, ...
# 25  [[3, 4, -2], [3, 8, 2], [-3, 7, 4], [-9, 5, 3]...
# 26  [[4, 9, 3], [7, 11, 3], [4, 10, 9], [5, 13, 9]...
# 27  [[27, 10, 11], [29, 11, 7], [29, 7, 8], [28, 1...
# 28  [[13, 13, 7], [18, 11, 7], [19, 10, 6], [17, 1...
# 29  [[6, 13, 8], [4, 10, 4], [0, 9, 3], [4, 8, 2],...
#
#                                                   Mag
# 0   [[5541, 1551, 2887], [5568, 1587, 2956], [5605...
# 1   [[5185, 2842, 2267], [5220, 2876, 2260], [5211...
# 2   [[5626, 2148, 3057], [5602, 2127, 3015], [5562...
# 3   [[5530, 2536, 2713], [5521, 2561, 2774], [5493...
# 4   [[5752, 2071, 2723], [5801, 2220, 2615], [5776...
# 5   [[5608, 2591, 2617], [5602, 2597, 2610], [5604...
# 6   [[5864, 1364, 3104], [5898, 1216, 3044], [5917...
# 7   [[5631, 2366, 1215], [5657, 2305, 1174], [5624...
# 8   [[5577, 837, 479], [5598, 814, 530], [5627, 93...
# 9   [[5717, 1934, 1281], [5738, 1945, 1379], [5688...
# 10  [[5639, 2232, 1305], [5653, 2113, 1387], [5654...
# 11  [[5432, 822, 219], [5435, 943, 33], [5447, 924...
# 12  [[5850, 1521, 1292], [5867, 1628, 1216], [5874...
# 13  [[5608, 1591, 535], [5661, 1597, 512], [5671, ...
# 14  [[5156, 685, -203], [5140, 700, -161], [5184, ...
# 15  [[5657, 2453, 1294], [5638, 2443, 1297], [5646...
# 16  [[5640, 2034, 1201], [5613, 2024, 1139], [5636...
# 17  [[5750, 1628, 1250], [5715, 1636, 1272], [5742...
# 18  [[5496, 2726, 1996], [5510, 2715, 2006], [5524...
# 19  [[5822, 1635, 3231], [5840, 1641, 3245], [5832...
# 20  [[5574, 1016, 2644], [5565, 983, 2705], [5570,...
# 21  [[4339, 156, 2811], [4359, -10, 2859], [4343, ...
# 22  [[4604, 206, 2010], [4580, 34, 2135], [4589, 5...
# 23  [[4230, 20, 2227], [4229, 25, 2269], [4235, 20...
# 24  [[3434, 3770, 962], [3436, 3749, 908], [3460, ...
# 25  [[307, 4760, 4095], [308, 4778, 4081], [294, 4...
# 26  [[700, 4389, 3828], [702, 4387, 3903], [679, 4...
# 27  [[1156, 3178, 3496], [1203, 3124, 3433], [1169...
# 28  [[1093, 3922, 4160], [1100, 3894, 4092], [1094...
# 29  [[1208, 2150, 6324], [1258, 2151, 6324], [1223...

# %%
newDF = FallAllD.drop(columns=['Acc', 'Gyr', 'Mag', 'Device', 'TrialNo'])    # Dropping those columns to bar graph activities done by eahc subject
newDF = newDF.groupby(['SubjectID', 'ActivityID']).count()
newDF.head(20)

#newDF.info()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(1, 13), (1, 14), (1, 15), (1, 16), (1, 18), (1, 19), (1, 20), (1, 21), (1, 22), (1, 23), (1, 24), (1, 25), (1, 26), (1, 27), (1, 28), (1, 29), (1, 30), (1, 31), (1, 32), (1, 33)]

# %%
newDF['Count'] = 1
newDF2 = newDF.groupby(['ActivityID']).count()['Count']
print(newDF2)
# Out:
# ActivityID
# 13     13
# 14     13
# 15     13
# 16     13
# 17     12
# 18     13
# 19     13
# 20     13
# 21     13
# 22     13
# 23     11
# 24     11
# 25     11
# 26     13
# 27     12
# 28     13
# 29     13
# 30     13
# 31     13
# 32     13
# 33     13
# 34     13
# 35     13
# 36     12
# 37     13
# 38     13
# 39     13
# 40     13
# 41      3
# 42      3
# 43     11
# 44     11
# 101     9
# 102     7
# 103     9
# 104     9
# 105    10
# 106     8
# 107     8
# 108     9
# 109     9
# 110     9
# 111     7
# 112     7
# 113     9
# 114    10
# 115     6
# 116     7
# 117     5
# 118     6
# 119     8
# 120     9
# 121    11
# 122     9
# 123    10
# 124    10
# 125    10
# 126     8
# 127     9
# 128     8
# Name: Count, dtype: int64

# %%
FallAllD.head()
# Out:
#    SubjectID Device  ActivityID  TrialNo  \
# 0          1  Waist          13        1
# 1          1  Waist          13        2
# 2          1  Waist          13        5
# 3          1  Waist          13        6
# 4          1  Waist          13        9
#
#                                                  Acc  \
# 0  [[4062, -1428, -45], [4190, -1422, -24], [4302...
# 1  [[3737, -1549, 158], [3729, -1553, 160], [3728...
# 2  [[3954, -401, -107], [3894, -346, -108], [3835...
# 3  [[3992, -682, -33], [3988, -694, -31], [3985, ...
# 4  [[2223, 167, -18], [2139, 222, -90], [2108, 25...
#
#                                                  Gyr  \
# 0  [[1355, 21, 159], [1334, -19, 168], [1318, -68...
# 1  [[-4, 0, -1], [-7, 11, -3], [-11, 11, -2], [-1...
# 2  [[177, 173, 177], [160, 183, 164], [152, 197, ...
# 3  [[12, 13, 9], [15, 12, 10], [11, 12, 9], [9, 1...
# 4  [[-396, -163, 33], [-338, -62, 54], [-272, 44,...
#
#                                                  Mag
# 0  [[5541, 1551, 2887], [5568, 1587, 2956], [5605...
# 1  [[5185, 2842, 2267], [5220, 2876, 2260], [5211...
# 2  [[5626, 2148, 3057], [5602, 2127, 3015], [5562...
# 3  [[5530, 2536, 2713], [5521, 2561, 2774], [5493...
# 4  [[5752, 2071, 2723], [5801, 2220, 2615], [5776...

# %%
stopWalking = FallAllD.loc[FallAllD['ActivityID'] == 28]
stopWalking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45 entries, 55 to 1724
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SubjectID   45 non-null     int8
#  1   Device      45 non-null     object
#  2   ActivityID  45 non-null     uint8
#  3   TrialNo     45 non-null     int8
#  4   Acc         45 non-null     object
#  5   Gyr         45 non-null     object
#  6   Mag         45 non-null     object
# dtypes: int8(2), object(4), uint8(1)
# memory usage: 1.9+ KB

# %%
accX = pd.DataFrame(stopWalking.iloc[0].Acc.tolist())[0]
accY = pd.DataFrame(stopWalking.iloc[0].Acc.tolist())[1]
accZ = pd.DataFrame(stopWalking.iloc[0].Acc.tolist())[2]

print(accX)
# Out:
# 0       3933
# 1       3936
# 2       3937
# 3       3938
# 4       3940
#         ...
# 4755    3838
# 4756    3835
# 4757    3832
# 4758    3826
# 4759    3818
# Name: 0, Length: 4760, dtype: int64

# %%
Fs_Acc = 238
Acc_Sen = 0.000244
accX = accX * Acc_Sen
accY = accY * Acc_Sen
accZ = accZ * Acc_Sen
t_Acc = []
for i in range(4760):
    t_Acc.append(i/Fs_Acc)

fig, ax1 = plt.subplots(3, sharex=True)
fig.suptitle('Bending down')
ax1[0].plot(t_Acc, accX, linewidth = 0.25)
ax1[1].plot(t_Acc, accY, linewidth = 0.25)
ax1[2].plot(t_Acc, accZ, linewidth = 0.25)
plt.show()
